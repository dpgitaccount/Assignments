# %%
Q1.
ANS-

Estimation statistics is a branch of statistics that focuses on making inferences or predictions about population parameters based on sample data. 
It involves using statistical methods to estimate unknown values or parameters, such as means, proportions, or variances, using information obtained from a sample.

Point estimate:-

A point estimate is a single value that is used to estimate an unknown population parameter.
It is calculated based on the sample data and provides an estimate of the true value of the parameter. For example, if you want to estimate the mean height of a population, you can calculate the mean height of a sample from that population and use it as a point estimate for the population mean. Point estimates are typically denoted by symbols such as "𝜃-hat" or "𝑝-hat" to indicate that they are estimates.

Interval estimate:-

An interval estimate, also known as an confidence interval, provides a range of values within which the true population parameter is likely to fall.
Unlike a point estimate that gives only a single value, an interval estimate accounts for the uncertainty associated with the estimation process. It is represented as a range with an associated level of confidence. For example, a 95% confidence interval for the population mean height would provide a range of values within which we can be 95% confident that the true population mean lies.

# %%
# Q2.
# ANS-

import math

def estimate_population_mean(sample_mean, sample_std_dev, sample_size):
    
    # Calculate the standard error
    standard_error = sample_std_dev / math.sqrt(sample_size)
    
    
    confidence_level = 0.95
    z_value = 1.96
    margin_of_error = z_value * standard_error
    
    # Calculate the lower and upper bounds of the confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    
    # Return the estimated population mean and the confidence interval
    return sample_mean, (lower_bound, upper_bound)

sample_mean = 50.0
sample_std_dev = 5.0
sample_size = 100

estimated_mean, confidence_interval = estimate_population_mean(sample_mean, sample_std_dev, sample_size)

print("Estimated Population Mean:", estimated_mean)
print("Confidence Interval:", confidence_interval)
# Out:
# Estimated Population Mean: 50.0
# Confidence Interval: (49.02, 50.98)

# %%
Q3.
ANS-
Hypothesis testing is a statistical technique used to make inferences or draw conclusions about a population based on sample data. 
It involves formulating a null hypothesis and an alternative hypothesis, collecting and analyzing data, and making a decision about which hypothesis is supported by the evidence.
The main purpose of hypothesis testing is to provide a framework for evaluating the validity of claims or assumptions about a population parameter. 
It allows researchers and analysts to make data-driven decisions and draw reliable conclusions.


Objective decision-making:-
Hypothesis testing provides a systematic and objective approach to decision-making. 
It allows researchers to move beyond subjective opinions and rely on statistical evidence to support or reject hypotheses.

Testing research questions:-
Hypothesis testing is crucial in scientific research as it enables researchers to test research questions or hypotheses.
By collecting and analyzing data, researchers can evaluate whether the evidence supports their initial assumptions or hypotheses.

Drawing generalizations:-
Hypothesis testing allows researchers to make generalizations about a larger population based on the information obtained from a smaller sample. 
By using statistical methods, researchers can infer characteristics of a population from a representative subset of data.

Controlling errors:-
Hypothesis testing provides a framework for controlling and managing errors in statistical analysis. 
By setting a predetermined level of significance, researchers can control the probability of making Type I and Type II errors, which are errors in rejecting or accepting a null hypothesis, respectively.

# %%
Q4.
ANS-

Hypothesis:
The average weight of male college students is greater than the average weight of female college students.

Symbolically, we can represent this hypothesis as:

Null hypothesis (H0): The average weight of male college students is equal to or less than the average weight of female college students.
Alternative hypothesis (Ha): The average weight of male college students is greater than the average weight of female college students.

In statistical terms:
H0: μ_male <= μ_female
Ha: μ_male > μ_female

Here, μ_male represents the population mean weight of male college students, and μ_female represents the population mean weight of female college students.

To test this hypothesis, we would collect a representative sample of male and female college students, measure their weights, calculate the sample means for both groups, and then perform a statistical test (such as a t-test or z-test) to determine whether there is sufficient evidence to reject the null hypothesis in favor of the alternative hypothesis.

The results of the test would indicate whether the average weight of male college students is  greater than the average weight of female college students or not.

# %%
# Q5.
# ANS-
import scipy.stats as stats

def hypothesis_test(sample1, sample2, alpha):
    # independent t-test assuming unequal variances
    t_statistic, p_value = stats.ttest_ind(sample1, sample2, equal_var=False)

    # Compare of p-value 
    if p_value < alpha:
        print("Reject the null hypothesis. There is evidence of a significant difference.")
    else:
        print("Fail to reject the null hypothesis. There is no significant difference.")

    
    return t_statistic, p_value


sample1 = [1.5, 2.0, 2.2, 1.8, 1.9]
sample2 = [1.2, 1.6, 1.8, 1.5, 2.1]
alpha = 0.05

t_statistic, p_value = hypothesis_test(sample1, sample2, alpha)

print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# Fail to reject the null hypothesis. There is no significant difference.
# T-statistic: 1.2649110640673527
# P-value: 0.2437413728691778

# %%
Q6.
ANS-
In hypothesis testing, the null hypothesis (H0) and the alternative hypothesis (Ha or H1) are two competing statements about a population parameter. 
These hypotheses are formulated based on the research question or the claim being investigated. 

Null Hypothesis (H0):-
The null hypothesis represents the status quo or the assumption of no effect or no difference. It states that there is no significant relationship, effect, or difference between variables, or that the population parameter takes a specific value. 
The null hypothesis is usually denoted as H0 and is initially assumed to be true.

Example 1:-
H0: There is no difference in test scores between students who received tutoring and those who did not.

Example 2:-
H0: The mean weight of a particular population is equal to 150 pounds.

# %%
Q7.
ANS-

State the hypotheses:-
Clearly define the null hypothesis (H0) and the alternative hypothesis (Ha or H1) based on the research question or claim being investigated. 
Specify the population parameter and the direction (if applicable) of the alternative hypothesis.

Set the significance level:-
Determine the significance level (α) for the hypothesis test.
This represents the maximum acceptable probability of making a Type I error (rejecting the null hypothesis when it is true).
Commonly used significance levels are 0.05 (5%) or 0.01 (1%).

Collect and analyze data:-
Collect a representative sample from the population of interest. 
Perform appropriate data analysis techniques to calculate summary statistics, such as sample means, proportions, or variances, depending on the specific hypothesis being tested.

Determine the test statistic:-
Calculate the test statistic based on the sample data and the chosen hypothesis test.
The test statistic measures the discrepancy between the observed sample data and the null hypothesis.

Calculate the p-value:-
Compute the p-value associated with the test statistic. 
The p-value represents the probability of obtaining a test statistic as extreme as, or more extreme than, the observed value, assuming the null hypothesis is true.

Make a decision:-
Compare the p-value to the significance level (α). 
If the p-value is less than α, there is sufficient evidence to reject the null hypothesis. If the p-value is greater than or equal to α, there is not enough evidence to reject the null hypothesis. 
Make a decision based on this comparison.

Interpret the results:-
Provide an interpretation of the decision made in the previous step. If the null hypothesis is rejected, interpret the results in the context of the alternative hypothesis. 
If the null hypothesis is not rejected, interpret the results cautiously, acknowledging that there is not enough evidence to support the alternative hypothesis.

# %%
Q8.
ANS-
The p-value is a statistical measure used in hypothesis testing to quantify the strength of evidence against the null hypothesis. 
It represents the probability of obtaining a test statistic as extreme as, or more extreme than, the observed value, assuming the null hypothesis is true. In simpler terms, the p-value measures the likelihood of observing the data or a more extreme result if the null hypothesis is actually true.

The significance of the p-value in hypothesis testing lies in its role in decision-making.

If p-value < α:-
If the p-value is less than the chosen significance level (α), typically 0.05 or 0.01, it indicates that the observed data is unlikely to occur under the assumption that the null hypothesis is true. 
In this case, there is sufficient evidence to reject the null hypothesis in favor of the alternative hypothesis.
The result is considered statistically significant, suggesting that there is a meaningful effect or difference.

If p-value ≥ α:-
If the p-value is greater than or equal to the significance level (α), it suggests that the observed data is reasonably likely to occur by chance even if the null hypothesis is true. 
In this case, there is not enough evidence to reject the null hypothesis. The result is considered statistically non-significant, indicating that any observed effect or difference may be due to random variability or other factors, rather than a true population effect.

# %%
# Q9.
# ANS-

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# degrees of freedom
df = 10

# Generate x-values
x = np.linspace(-4, 4, 500)

# Calculate ty-values from the t-distribution
y = t.pdf(x, df)

# Create the plot
plt.plot(x, y, label=f't-distribution (df = {df})')
plt.xlabel('x')
plt.ylabel('Probability Density Function')
plt.title(f'Student\'s t-distribution (df = {df})')


plt.legend()

plt.show()

# %%
# Q10.
# ANS-

import numpy as np
from scipy.stats import ttest_ind

def two_sample_t_test(sample1, sample2):
    t_statistic, p_value = ttest_ind(sample1, sample2)

    return t_statistic, p_value

sample1 = np.array([1.5, 2.0, 2.2, 1.8, 1.9])
sample2 = np.array([1.2, 1.6, 1.8, 1.5, 2.1])

t_statistic, p_value = two_sample_t_test(sample1, sample2)

print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: 1.2649110640673527
# P-value: 0.2415039719130598

# %%
Q11.
ANS-

Student's t-distribution, often referred to as the t-distribution, is a probability distribution that arises in statistical inference. It is used when the sample size is small and the population standard deviation is unknown. The t-distribution is similar to the standard normal distribution (Z-distribution), but it has heavier tails, allowing for more uncertainty in the estimates.

The t-distribution is characterized by its degrees of freedom (df). The degrees of freedom determine the shape of the distribution. As the degrees of freedom increase, the t-distribution approaches the shape of the standard normal distribution.

The t-distribution is commonly used in the following situations:

Small sample sizes:-
When working with small samples (typically less than 30), the t-distribution is used to estimate population parameters, such as the mean, when the population standard deviation is unknown. This is in contrast to the standard normal distribution, which is used for large sample sizes (typically greater than 30) or when the population standard deviation is known.

Confidence intervals:-
The t-distribution is used to construct confidence intervals for population parameters when the sample size is small and the population standard deviation is unknown. The wider confidence intervals account for the increased uncertainty associated with smaller sample sizes.

Hypothesis testing:-
In hypothesis testing, the t-distribution is used when testing hypotheses about population means or differences between means, especially when the sample size is small and the population standard deviation is unknown. It is employed to calculate the test statistic and determine the p-value, which helps in drawing conclusions about the hypotheses.

Comparison of means:-
When comparing means between two groups (e.g., treatment vs. control), the t-distribution is used to perform statistical tests, such as the independent samples t-test or paired samples t-test.

# %%
Q12.
ANS-

The t-statistic is a measure that quantifies the difference between a sample mean and a hypothesized population mean, relative to the variability observed in the sample.
It is used in hypothesis testing to assess whether the observed difference in means is statistically significant.

The formula for the t-statistic depends on the specific context and type of t-test being conducted.
Here are the formulas for two common types of t-tests:

One-sample t-test:-
In a one-sample t-test, the t-statistic compares the sample mean to a hypothesized population mean. 
The formula for the t-statistic in a one-sample t-test is:

t = (sample_mean - hypothesized_mean) / (sample_standard_deviation / sqrt(sample_size))

Where:

sample_mean is the mean of the sample.
hypothesized_mean is the hypothesized population mean.
sample_standard_deviation is the standard deviation of the sample.
sample_size is the size of the sample.


Independent samples t-test:-
In an independent samples t-test, the t-statistic compares the means of two independent samples. The formula for the t-statistic in an independent samples t-test is:

t = (sample_mean1 - sample_mean2) / sqrt((sample_variance1 / sample_size1) + (sample_variance2 / sample_size2))

Where:

sample_mean1 and sample_mean2 are the means of the two samples.
sample_variance1 and sample_variance2 are the variances of the two samples.
sample_size1 and sample_size2 are the size

# %%
Q13.
ANS-

To estimate the population mean revenue with a 95% confidence interval, we can use the sample mean and standard deviation along with the concept of a confidence interval.

Given:
Sample size (n) = 50
Sample mean (x̄) = $500
Sample standard deviation (s) = $50

To calculate the 95% confidence interval, 

Confidence Interval = sample mean ± (critical value * standard error)

Calculate the standard error:
Standard Error (SE) = sample standard deviation / √(sample size)
SE = $50 / √(50) ≈ $7.07

Determine the critical value:
For a 95% confidence level, the critical value corresponds to the two-tailed z-score. Since the sample size is large enough, we can use the standard normal distribution.
The critical value for a 95% confidence level is approximately 1.96 (obtained from a standard normal distribution table or using statistical software).

Calculate the confidence interval:
Confidence Interval = sample mean ± (critical value * standard error)
CI = $500 ± (1.96 * $7.07)
CI ≈ $500 ± $13.85

The 95% confidence interval for the average daily revenue of the coffee shop is approximately $486.15 to $513.85.

Therefore, we can estimate that with 95% confidence, the true population mean revenue for the coffee shop falls within the range of $486.15 to $513.85 based on the given sample data.

# %%
Q14.
ANS-

To test the hypothesis that the new drug decreases blood pressure by 10 mmHg, we can perform a one-sample t-test. Here's how you can conduct the hypothesis test with a significance level of 0.05:

Given:
Null hypothesis (H0): The new drug does not decrease blood pressure by 10 mmHg.
Alternative hypothesis (Ha): The new drug decreases blood pressure by 10 mmHg.
Sample size (n) = 100
Sample mean (x̄) = 8 mmHg
Sample standard deviation (s) = 3 mmHg
Significance level (α) = 0.05

Set up the hypotheses:
H0: μ = 10 (The population mean decrease in blood pressure is 10 mmHg)
Ha: μ < 10 (The population mean decrease in blood pressure is less than 10 mmHg)

Determine the test statistic:-
Calculate the t-statistic using the formula:
t = (sample mean - hypothesized mean) / (sample standard deviation / √sample size)
t = (8 - 10) / (3 / √100)
t = -2 / 0.3
t ≈ -6.67

critical value:-
Since the alternative hypothesis is one-sided (μ < 10), we need to find the critical value from the t-distribution with (n - 1) degrees of freedom at the desired significance level.
With 99 degrees of freedom and a significance level of 0.05, the critical value is approximately -1.660 (obtained from a t-distribution table or using statistical software).

Compare the test statistic with the critical value:-
If the test statistic is less than the critical value, we reject the null hypothesis; otherwise, we fail to reject the null hypothesis.

-6.67 < -1.660

Since the test statistic falls in the rejection region, we reject the null hypothesis.

p-value:-
The p-value is the probability of observing a test statistic as extreme as the one calculated, assuming the null hypothesis is true. Since the test statistic is negative and we have a one-sided alternative hypothesis, the p-value can be obtained from the t-distribution's cumulative distribution function (CDF) with (n - 1) degrees of freedom.
The p-value is very small, and for practical purposes, it is essentially 0 (p < 0.0001).

conclusion:-
Based on the results, we have sufficient evidence to conclude that the new drug decreases blood pressure by less than 10 mmHg at a significance level of 0.05. The sample data suggests a mean decrease of 8 mmHg, which is significantly lower than the hypothesized mean of 10 mmHg.

# %%
Q15
ANS-

To test the hypothesis that the true mean weight of the products is less than 5 pounds, we can perform a one-sample t-test. Here's how you can conduct the hypothesis test with a significance level of 0.01:

Given:
Null hypothesis (H0): The true mean weight of the products is 5 pounds.
Alternative hypothesis (Ha): The true mean weight of the products is less than 5 pounds.
Sample size (n) = 25
Sample mean (x̄) = 4.8 pounds
Population standard deviation (σ) = 0.5 pounds
Significance level (α) = 0.01

Set up the hypotheses:
H0: μ = 5 (The true mean weight of the products is 5 pounds)
Ha: μ < 5 (The true mean weight of the products is less than 5 pounds)

Determine the test statistic:
Calculate the t-statistic using the formula:
t = (sample mean - hypothesized mean) / (sample standard deviation / √sample size)
t = (4.8 - 5) / (0.5 / √25)
t = -0.2 / 0.1
t = -2

Determine the critical value:
Since the alternative hypothesis is one-sided (μ < 5), we need to find the critical value from the t-distribution with (n - 1) degrees of freedom at the desired significance level.
With 24 degrees of freedom and a significance level of 0.01, the critical value is approximately -2.492 (obtained from a t-distribution table or using statistical software).

Compare the test statistic with the critical value:
If the test statistic is less than the critical value, we reject the null hypothesis; otherwise, we fail to reject the null hypothesis.

-2 < -2.492

Since the test statistic falls in the rejection region, we reject the null hypothesis.

Determine the p-value:
The p-value is the probability of observing a test statistic as extreme as the one calculated, assuming the null hypothesis is true. Since the test statistic is negative and we have a one-sided alternative hypothesis, the p-value can be obtained from the t-distribution's cumulative distribution function (CDF) with (n - 1) degrees of freedom.
The p-value is very small, and for practical purposes, it is less than 0.01 (p < 0.01).

Draw the conclusion:
Based on the results, we have sufficient evidence to conclude that the true mean weight of the products is less than 5 pounds at a significance level of 0.01. The sample data suggests a mean weight of 4.8 pounds, which is significantly lower than the hypothesized mean of 5 pounds.

# %%
Q16.
ANS-
To test the hypothesis that the population means for the two groups are equal, we can perform a two-sample t-test for independent samples. Here's how you can conduct the hypothesis test with a significance level of 0.01:

Given:
First group:

Sample size (n1) = 30
Sample mean (x̄1) = 80
Sample standard deviation (s1) = 10
Second group:

Sample size (n2) = 40
Sample mean (x̄2) = 75
Sample standard deviation (s2) = 8
Significance level (α) = 0.01

Set up the hypotheses:
H0: μ1 = μ2 (The population means for the two groups are equal)
Ha: μ1 ≠ μ2 (The population means for the two groups are not equal)

Determine the test statistic:
Calculate the pooled standard deviation (sp) using the formula:
sp = √((s1^2 / n1) + (s2^2 / n2))
sp = √((10^2 / 30) + (8^2 / 40))
sp ≈ 3.16

Calculate the t-statistic using the formula:
t = (x̄1 - x̄2) / (sp * √(1/n1 + 1/n2))
t = (80 - 75) / (3.16 * √(1/30 + 1/40))
t ≈ 2.82

Determine the critical value:
Since the alternative hypothesis is two-sided (μ1 ≠ μ2), we need to find the critical values from the t-distribution with (n1 + n2 - 2) degrees of freedom at the desired significance level.
With (30 + 40 - 2) = 68 degrees of freedom and a significance level of 0.01, the critical values are approximately -2.626 and 2.626 (obtained from a t-distribution table or using statistical software).

Compare the test statistic with the critical values:
If the test statistic is outside the range defined by the critical values, we reject the null hypothesis; otherwise, we fail to reject the null hypothesis.

-2.626 < 2.82 < 2.626

Since the test statistic falls within the range, we fail to reject the null hypothesis.

Determine the p-value:
The p-value is the probability of observing a test statistic as extreme as the one calculated, assuming the null hypothesis is true. Since the alternative hypothesis is two-sided, the p-value can be obtained by multiplying the probability of the observed test statistic by 2 (considering both tails of the t-distribution).
The p-value is greater than 0.01 (p > 0.01).

Draw the conclusion:
Based on the results, we do not have sufficient evidence to reject the null hypothesis that the population means for the two groups are equal at a significance level of 0.01. There is no significant difference in the mean scores between the two groups based on the given sample data.

# %%
Q17.
ANS-

To estimate the population mean number of ads watched by viewers during a TV program with a 99% confidence interval, we can use the sample mean and standard deviation along with the concept of a confidence interval. Here's how you can calculate it:

Given:
Sample size (n) = 50
Sample mean (x̄) = 4
Sample standard deviation (s) = 1.5

To calculate the 99% confidence interval

Confidence Interval = sample mean ± (critical value * standard error)

Calculate the standard error:
Standard Error (SE) = sample standard deviation / √(sample size)
SE = 1.5 / √(50) ≈ 0.2121

Determine the critical value:
For a 99% confidence level, the critical value corresponds to the two-tailed z-score. Since the sample size is large enough, we can use the standard normal distribution.
The critical value for a 99% confidence level is approximately 2.576 (obtained from a standard normal distribution table or using statistical software).

Calculate the confidence interval:
Confidence Interval = sample mean ± (critical value * standard error)
CI = 4 ± (2.576 * 0.2121)
CI ≈ 4 ± 0.5460

The 99% confidence interval for the average number of ads watched by viewers during a TV program is approximately 3.454 to 4.546.

Therefore, we can estimate that with 99% confidence, the true population mean number of ads watched by viewers during a TV program falls within the range of 3.454 to 4.546 based on the given sample data.
